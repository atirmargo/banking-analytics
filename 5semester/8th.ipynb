# %% [markdown]
# №1.Построить график функции y1−α+β − yβ для β ∈ (0, α), где yt – квантиль распределения
#
# (a) N(0, 1),
#
# (b) Gamma(n, 1), n = 1, 2, 5, 10, 100,
#
# (c) R[0, 1],
#
# (d) Beta(a, b), a = b = 5, a = 10, b = 2, a = 20, b = 1.
#
# Рассмотреть одно любое значение α, например, α = 0.001, 0.05, 0.1. Сделать вывод о выборе оптимального β для построения доверительного интервала на основе статистики с нашим распределением.

# %%
import numpy as np
import matplotlib.pyplot as plt
#ppf = Percent Point Function = Обратная функция распределения = квантиль
def conf_int_len(dist, alpha, beta):
    if beta <= 0 or beta >= alpha:
        return np.inf   #почему? потому что F^{-1}(0)=-inf  и F^{-1}(1 - alpha + alpha) = F^{-1}(1)= +inf
    y_beta = dist.ppf(beta)
    y_1_alpha_beta = dist.ppf(1 - alpha + beta)
    return y_1_alpha_beta - y_beta

from scipy.optimize import minimize
def find_optimal_beta(dist, alpha):
    beta_init = alpha / 2
    bounds = [(1e-6, alpha - 1e-6)]
    result = minimize(lambda beta: conf_int_len(dist, alpha, beta), beta_init, bounds=bounds)
    return result.x[0]

def plot_conf_int_len(dist, dist_name, alpha=0.001):
    beta_values = np.linspace(1e-6, alpha - 1e-6, 1000)
    lengths = []
    for beta in beta_values:
        length = conf_int_len(dist, alpha, beta)
        lengths.append(length)
    
    beta_opt = find_optimal_beta(dist, alpha)
    min_len = conf_int_len(dist, alpha, beta_opt)
    
    plt.figure(figsize=(5, 3))
    plt.plot(beta_values, lengths, label=dist_name)
    plt.scatter(beta_opt, min_len, color='red', s=50, label = 'beta_opt')
    
    plt.xlabel('β')
    plt.ylabel('Длина доверительного интервала')
    plt.title(f'{dist_name}, α={alpha}')
    plt.legend()
    plt.show()
    
    print(f"{dist_name}: β_opt={beta_opt}, min длина={min_len}")
    
    return beta_opt, min_len

from scipy.stats import norm, gamma, uniform, beta

alpha = 0.001


norm_dist = norm(0, 1)
beta_opt_norm, min_len_norm = plot_conf_int_len(norm_dist, "N(0,1)", alpha)

for n in [1, 2, 5, 10, 100]:
    gamma_dist = gamma(n, scale=1)
    beta_gamma, len_gamma = plot_conf_int_len(gamma_dist, f"Gamma({n},1)", alpha)

uniform_dist = uniform(0, 1)
beta_opt_unif, min_len_unif = plot_conf_int_len(uniform_dist, "U[0,1]", alpha)

for a, b in [(5, 5), (10, 2), (20, 1)]:
    beta_dist = beta(a, b)
    beta_beta, len_beta = plot_conf_int_len(beta_dist, f"Beta({a},{b})", alpha)
# Out:
# N(0,1): β_opt=0.0005, min длина=6.581053462983758
# Gamma(1,1): β_opt=1e-06, min длина=6.908754779315249
# Gamma(2,1): β_opt=1e-06, min длина=9.233107446114246
# Gamma(5,1): β_opt=6.0251724419919264e-05, min длина=14.478319082165218
# Gamma(10,1): β_opt=0.00015597601390493807, min длина=20.603661003321562
# Gamma(100,1): β_opt=0.00038243485538972305, min длина=65.73524150904579
# U[0,1]: β_opt=0.0005, min длина=0.999
# Beta(5,5): β_opt=0.0005, min длина=0.8233048346749122
# Beta(10,2): β_opt=0.0009963922628936296, min длина=0.5865439979769408
# Beta(20,1): β_opt=0.000999, min длина=0.29208957972970684

# %% [markdown]
# №2. X1, ..., Xn ∼ R[0, θ].
#
# (a) Построить асимптотический доверительный интервал, используя X. Найти эмпирически доверительную вероятность этого интервала (построить 1000 выборок, подсчитать долю тех, для которых интервал накрыл истинное значение параметра, для n = 20, 50, 100)
#
# (b) Построить точный доверительный интервал, используя достаточную статистику. Сравнить средние длины точного и асимптотического интервалов при n = 20, 50, 100.

# %%
from scipy import stats
def find_asymp_interval(theta_true, N_simulations):
    for n in n_values: 
        length = []
        good = 0  
        for i in range(N_simulations):
            sample = np.random.uniform(0, theta_true, n)
            theta_lower = 2*np.mean(sample)/(z2/np.sqrt(3*n) + 1)
            theta_upper = 2*np.mean(sample)/(z1/np.sqrt(3*n) + 1)
            length.append(theta_upper - theta_lower)
            if theta_lower <= theta_true <= theta_upper:
                good += 1
        emp_probability = good/N_simulations
        asymp_length = np.mean(length)
        print(f"Размер выборки {n}, эмпирическая вероятность {emp_probability}, средняя длина {asymp_length}")
    return emp_probability, asymp_length
 
def find_exact_interval(theta_true, N_simulations, alpha):
    for n in n_values:
        length = []
        for i in range(N_simulations):
            sample = np.random.uniform(0, theta_true, n)
            X_max = np.max(sample) #достаточная статистика
            theta_lower = X_max
            theta_upper = X_max / ((alpha)**(1/n))
            length.append(theta_upper - theta_lower)
        exact_length = np.mean(length)
        print(f"Размер выборки {n}, средняя длина {exact_length}")
    return exact_length

theta_true = 1  
n_values = [20, 50, 100]
N_simulations = 1000
alpha = 0.05  
z1 = stats.norm.ppf(alpha/2)
z2 = stats.norm.ppf(1 - alpha/2)

find_asymp_interval(theta_true, N_simulations)        
find_exact_interval(theta_true, N_simulations, alpha)
# Out:
# Размер выборки 20, эмпирическая вероятность 0.953, средняя длина 0.5417113264313109
# Размер выборки 50, эмпирическая вероятность 0.955, средняя длина 0.32858625089224164
# Размер выборки 100, эмпирическая вероятность 0.944, средняя длина 0.22913266134973168
# Размер выборки 20, средняя длина 0.15380352576013007
# Размер выборки 50, средняя длина 0.06059881006836008
# Размер выборки 100, средняя длина 0.030106853828635222
# np.float64(0.030106853828635222)

# %% [markdown]
# 3. X1, ..., Xn ∼ Bern(θ). а) Построить асимптотический доверительный интервал двумя способами
# с помощью X, сравнить средние длины полученных интервалов (генерировать 1000 выборок, по
# каждой строить оба интервала, посчитать и показать средние длины) для θ = 0.1, 0.4, 0.5, 0.9 и
# n = 20, 50, 100. б) Найти точный уровень доверия в зависимости от n и построить график при n
# от 20 до 100.
# ![dg](asymp_conf_int.jpg)

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats
def bild_asymp_int (n_values, theta_values, N_simulations):
    for theta in theta_values:
        level_of_trust_1 = []
        level_of_trust_2 = []
        for n in n_values: 
            length_1 = []
            length_2 = []
            good_1 = 0
            good_2 = 0
            for i in range(N_simulations):
                sample = np.random.binomial(1, theta, n)
                #Способ 1. Подстановка оценки σ̂ = σ(θ̂), θ̂  = np.mean(sample)
                mean = np.mean(sample) #асимптотически нормальная оценка
                theta_lower_1 = mean - z2 * np.sqrt(mean*(1 - mean) / n)
                theta_upper_1 = mean - z1 * np.sqrt(mean*(1 - mean) / n)
                length_1.append(theta_upper_1 - theta_lower_1)
                if theta_lower_1 <= theta <= theta_upper_1:
                    good_1 += 1
                #Способ 2. Стабилизация асимптотической дисперсии g(θ) = arcsin(2θ - 1) => g^-1 = (sin(θ)+1)/2
                left = np.arcsin(mean*2 - 1) - z2 / np.sqrt(n)
                right = np.arcsin(mean*2 - 1) - z1 / np.sqrt(n)
                theta_lower_2 = (np.sin(left) + 1) / 2
                theta_upper_2 = (np.sin(right) + 1) / 2
                length_2.append(theta_upper_2 - theta_lower_2)
                if theta_lower_2 <= theta <= theta_upper_2:
                    good_2 += 1
            mean_len_1 = np.mean(length_1)
            mean_len_2 = np.mean(length_2)
            lev_of_trust_1 = good_1 / N_simulations
            lev_of_trust_2 = good_2 / N_simulations
            level_of_trust_1.append(lev_of_trust_1)
            level_of_trust_2.append(lev_of_trust_2)
            print(f"Параметр θ = {theta}, размер выборки {n}\n Способ 1 : средняя длина {mean_len_1}, уровень доверия {lev_of_trust_1}\n Способ 2 : средняя длина {mean_len_2}, уровень доверия {lev_of_trust_2}\n")
        #Визуализируем
        plt.figure(figsize=(10, 6))
        plt.plot(n_values, level_of_trust_1, color='green', label='Способ 1')
        plt.plot(n_values, level_of_trust_2, color='blue', label='Способ 2')

        plt.xlabel('n')
        plt.ylabel('Уровень доверия')
        plt.legend()
        plt.show()

n_values = np.arange(20, 100, 2)
theta_values = [0.1, 0.4, 0.5, 0.9]
N_simulations = 1000
alpha = 0.05
z1 = stats.norm.ppf(alpha/2)
z2 = stats.norm.ppf(1 - alpha/2) #-z1

bild_asymp_int (n_values, theta_values, N_simulations)
# Out:
# Параметр θ = 0.1, размер выборки 20
#  Способ 1 : средняя длина 0.23598008372018076, уровень доверия 0.888
#  Способ 2 : средняя длина 0.2284980695505668, уровень доверия 0.882
#
# Параметр θ = 0.1, размер выборки 22
#  Способ 1 : средняя длина 0.22445464661866094, уровень доверия 0.9
#  Способ 2 : средняя длина 0.21797936859713238, уровень доверия 0.889
#
# Параметр θ = 0.1, размер выборки 24
#  Способ 1 : средняя длина 0.2198952030930614, уровень доверия 0.913
#  Способ 2 : средняя длина 0.21407587142983356, уровень доверия 0.895
#
# Параметр θ = 0.1, размер выборки 26
#  Способ 1 : средняя длина 0.2116496517713104, уровень доверия 0.934
#  Способ 2 : средняя длина 0.20647620168439304, уровень доверия 0.929
#
# Параметр θ = 0.1, размер выборки 28
#  Способ 1 : средняя длина 0.2089534204799961, уровень доверия 0.944
#  Способ 2 : средняя длина 0.20420819614072797, уровень доверия 0.924
#
# Параметр θ = 0.1, размер выборки 30
#  Способ 1 : средняя длина 0.2027231220331907, уровень доверия 0.812
#  Способ 2 : средняя длина 0.19842433431307757, уровень доверия 0.944
#
# Параметр θ = 0.1, размер выборки 32
#  Способ 1 : средняя длина 0.19744417946908868, уровень доверия 0.847
#  Способ 2 : средняя длина 0.19351743934173288, уровень доверия 0.949
#
# Параметр θ = 0.1, размер выборки 34
#  Способ 1 : средняя длина 0.18859157241255503, уровень доверия 0.852
#  Способ 2 : средняя длина 0.18506027294624736, уровень доверия 0.94
#
# Параметр θ = 0.1, размер выборки 36
#  Способ 1 : средняя длина 0.1814482912808216, уровень доверия 0.864
#  Способ 2 : средняя длина 0.17823849179742957, уровень доверия 0.949
#
# Параметр θ = 0.1, размер выборки 38
#  Способ 1 : средняя длина 0.18299579724738857, уровень доверия 0.879
#  Способ 2 : средняя длина 0.17992813866019805, уровень доверия 0.977
#
# Параметр θ = 0.1, размер выборки 40
#  Способ 1 : средняя длина 0.17518168004264564, уровень доверия 0.898
#  Способ 2 : средняя длина 0.17239114176560344, уровень доверия 0.893
#
# Параметр θ = 0.1, размер выборки 42
#  Способ 1 : средняя длина 0.17387200915098389, уровень доверия 0.92
#  Способ 2 : средняя длина 0.1712336191185841, уровень доверия 0.903
#
# Параметр θ = 0.1, размер выборки 44
#  Способ 1 : средняя длина 0.16948666617597583, уровень доверия 0.923
#  Способ 2 : средняя длина 0.16703121234584103, уровень доверия 0.923
#
# Параметр θ = 0.1, размер выборки 46
#  Способ 1 : средняя длина 0.16921245506991453, уровень доверия 0.944
#  Способ 2 : средняя длина 0.16686711485376754, уровень доверия 0.937
#
# Параметр θ = 0.1, размер выборки 48
#  Способ 1 : средняя длина 0.16321838568739178, уровень доверия 0.862
#  Способ 2 : средняя длина 0.16105000880121312, уровень доверия 0.939
#
# Параметр θ = 0.1, размер выборки 50
#  Способ 1 : средняя длина 0.1602977410364797, уровень доверия 0.878
#  Способ 2 : средняя длина 0.1582530209995497, уровень доверия 0.952
#
# Параметр θ = 0.1, размер выборки 52
#  Способ 1 : средняя длина 0.15808913432645974, уровень доверия 0.897
#  Способ 2 : средняя длина 0.15614985972104187, уровень доверия 0.954
#
# Параметр θ = 0.1, размер выборки 54
#  Способ 1 : средняя длина 0.1560350696849896, уровень доверия 0.911
#  Способ 2 : средняя длина 0.15419163176973474, уровень доверия 0.956
#
# Параметр θ = 0.1, размер выборки 56
#  Способ 1 : средняя длина 0.1534296295941165, уровень доверия 0.907
#  Способ 2 : средняя длина 0.1516814886512999, уровень доверия 0.891
#
# Параметр θ = 0.1, размер выборки 58
#  Способ 1 : средняя длина 0.1509334547879249, уровень доверия 0.927
#  Способ 2 : средняя длина 0.14927285825390982, уровень доверия 0.916
#
# Параметр θ = 0.1, размер выборки 60
#  Способ 1 : средняя длина 0.14758643382236733, уровень доверия 0.945
#  Способ 2 : средняя длина 0.1460166142337224, уровень доверия 0.94
#
# Параметр θ = 0.1, размер выборки 62
#  Способ 1 : средняя длина 0.1469015878035743, уровень доверия 0.959
#  Способ 2 : средняя длина 0.1453893008340463, уровень доверия 0.953
#
# Параметр θ = 0.1, размер выборки 64
#  Способ 1 : средняя длина 0.14367499351167215, уровень доверия 0.89
#  Способ 2 : средняя длина 0.1422420051194806, уровень доверия 0.932
#
# Параметр θ = 0.1, размер выборки 66
#  Способ 1 : средняя длина 0.1422229369111135, уровень доверия 0.878
#  Способ 2 : средняя длина 0.1408472909761673, уровень доверия 0.948
#
# Параметр θ = 0.1, размер выборки 68
#  Способ 1 : средняя длина 0.13988662408566155, уровень доверия 0.904
#  Способ 2 : средняя длина 0.13857325915131294, уровень доверия 0.951
#
# Параметр θ = 0.1, размер выборки 70
#  Способ 1 : средняя длина 0.13737795739062034, уровень доверия 0.923
#  Способ 2 : средняя длина 0.13612489640481862, уровень доверия 0.954
#
# Параметр θ = 0.1, размер выборки 72
#  Способ 1 : средняя длина 0.13702920486818626, уровень доверия 0.931
#  Способ 2 : средняя длина 0.1358139511995305, уровень доверия 0.911
#
# Параметр θ = 0.1, размер выборки 74
#  Способ 1 : средняя длина 0.13374124322336786, уровень доверия 0.948
#  Способ 2 : средняя длина 0.13258712246588203, уровень доверия 0.944
#
# Параметр θ = 0.1, размер выборки 76
#  Способ 1 : средняя длина 0.13200888114509923, уровень доверия 0.941
#  Способ 2 : средняя длина 0.13089961223314764, уровень доверия 0.932
#
# Параметр θ = 0.1, размер выборки 78
#  Способ 1 : средняя длина 0.12988720286831396, уровень доверия 0.948
#  Способ 2 : средняя длина 0.1288236791202536, уровень доверия 0.942
#
# Параметр θ = 0.1, размер выборки 80
#  Способ 1 : средняя длина 0.12931444465435568, уровень доверия 0.919
#  Способ 2 : средняя длина 0.12828201796868777, уровень доверия 0.949
#
# Параметр θ = 0.1, размер выборки 82
#  Способ 1 : средняя длина 0.12753445264754792, уровень доверия 0.913
#  Способ 2 : средняя длина 0.12654101348993096, уровень доверия 0.953
#
# Параметр θ = 0.1, размер выборки 84
#  Способ 1 : средняя длина 0.12601133932681371, уровень доверия 0.924
#  Способ 2 : средняя длина 0.1250530819550682, уровень доверия 0.949
#
# Параметр θ = 0.1, размер выборки 86
#  Способ 1 : средняя длина 0.124936915289217, уровень доверия 0.927
#  Способ 2 : средняя длина 0.12400887410024958, уровень доверия 0.956
#
# Параметр θ = 0.1, размер выборки 88
#  Способ 1 : средняя длина 0.1225995626650109, уровень доверия 0.921
#  Способ 2 : средняя длина 0.12170953558707939, уровень доверия 0.921
#
# Параметр θ = 0.1, размер выборки 90
#  Способ 1 : средняя длина 0.12232770964151982, уровень доверия 0.944
#  Способ 2 : средняя длина 0.12145934851625506, уровень доверия 0.938
#
# Параметр θ = 0.1, размер выборки 92
#  Способ 1 : средняя длина 0.12073926320429187, уровень доверия 0.939
#  Способ 2 : средняя длина 0.11990077128312086, уровень доверия 0.927
#
# Параметр θ = 0.1, размер выборки 94
#  Способ 1 : средняя длина 0.11914836422895506, уровень доверия 0.897
#  Способ 2 : средняя длина 0.11833848975157267, уровень доверия 0.939
#
# Параметр θ = 0.1, размер выборки 96
#  Способ 1 : средняя длина 0.11834144483771755, уровень доверия 0.916
#  Способ 2 : средняя длина 0.11755377973315018, уровень доверия 0.959
#
# Параметр θ = 0.1, размер выборки 98
#  Способ 1 : средняя длина 0.11601839060229201, уровень доверия 0.917
#  Способ 2 : средняя длина 0.1152619157990731, уровень доверия 0.952
# Параметр θ = 0.4, размер выборки 20
#  Способ 1 : средняя длина 0.417375134272172, уровень доверия 0.928
#  Способ 2 : средняя длина 0.404141785849549, уровень доверия 0.928
#
# Параметр θ = 0.4, размер выборки 22
#  Способ 1 : средняя длина 0.39920797206682795, уровень доверия 0.949
#  Способ 2 : средняя длина 0.3876912463207348, уровень доверия 0.949
#
# Параметр θ = 0.4, размер выборки 24
#  Способ 1 : средняя длина 0.3832577957631828, уровень доверия 0.94
#  Способ 2 : средняя длина 0.3731152178683857, уровень доверия 0.94
#
# Параметр θ = 0.4, размер выборки 26
#  Способ 1 : средняя длина 0.3693907486614418, уровень доверия 0.931
#  Способ 2 : средняя длина 0.3603615601663249, уровень доверия 0.967
#
# Параметр θ = 0.4, размер выборки 28
#  Способ 1 : средняя длина 0.3557530925859032, уровень доверия 0.949
#  Способ 2 : средняя длина 0.3476741234556987, уровень доверия 0.949
#
# Параметр θ = 0.4, размер выборки 30
#  Способ 1 : средняя длина 0.34570959133592793, уровень доверия 0.949
#  Способ 2 : средняя длина 0.3383787445580409, уровень доверия 0.949
#
# Параметр θ = 0.4, размер выборки 32
#  Способ 1 : средняя длина 0.3342153491220291, уровень доверия 0.953
#  Способ 2 : средняя длина 0.3275685245556906, уровень доверия 0.953
#
# Параметр θ = 0.4, размер выборки 34
#  Способ 1 : средняя длина 0.32454721957238497, уровень доверия 0.963
#  Способ 2 : средняя длина 0.3184702066464813, уровень доверия 0.963
#
# Параметр θ = 0.4, размер выборки 36
#  Способ 1 : средняя длина 0.3161478695944935, уровень доверия 0.956
#  Способ 2 : средняя длина 0.31055525000388295, уровень доверия 0.975
#
# Параметр θ = 0.4, размер выборки 38
#  Способ 1 : средняя длина 0.30643759295857476, уровень доверия 0.939
#  Способ 2 : средняя длина 0.3013006120682073, уровень доверия 0.939
#
# Параметр θ = 0.4, размер выборки 40
#  Способ 1 : средняя длина 0.29964662398145414, уровень доверия 0.952
#  Способ 2 : средняя длина 0.294873434378505, уровень доверия 0.952
#
# Параметр θ = 0.4, размер выборки 42
#  Способ 1 : средняя длина 0.2927408733092927, уровень доверия 0.942
#  Способ 2 : средняя длина 0.2882987287341728, уровень доверия 0.968
#
# Параметр θ = 0.4, размер выборки 44
#  Способ 1 : средняя длина 0.28625441034344934, уровень доверия 0.956
#  Способ 2 : средняя длина 0.28210727296604055, уровень доверия 0.956
#
# Параметр θ = 0.4, размер выборки 46
#  Способ 1 : средняя длина 0.27978255416136316, уровень доверия 0.955
#  Способ 2 : средняя длина 0.275904676047841, уровень доверия 0.955
#
# Параметр θ = 0.4, размер выборки 48
#  Способ 1 : средняя длина 0.2741978147113306, уровень доверия 0.917
#  Способ 2 : средняя длина 0.2705550620817371, уровень доверия 0.939
#
# Параметр θ = 0.4, размер выборки 50
#  Способ 1 : средняя длина 0.26919978522221233, уровень доверия 0.938
#  Способ 2 : средняя длина 0.26576593649033375, уровень доверия 0.938
#
# Параметр θ = 0.4, размер выборки 52
#  Способ 1 : средняя длина 0.2636269417848099, уровень доверия 0.937
#  Способ 2 : средняя длина 0.26039303810328607, уровень доверия 0.937
#
# Параметр θ = 0.4, размер выборки 54
#  Способ 1 : средняя длина 0.2591947120857425, уровень доверия 0.943
#  Способ 2 : средняя длина 0.2561325199730524, уровень доверия 0.955
#
# Параметр θ = 0.4, размер выборки 56
#  Способ 1 : средняя длина 0.25462817192653275, уровень доверия 0.951
#  Способ 2 : средняя длина 0.25172699870649146, уровень доверия 0.951
#
# Параметр θ = 0.4, размер выборки 58
#  Способ 1 : средняя длина 0.250064792867704, уровень доверия 0.938
#  Способ 2 : средняя длина 0.2473135358392421, уровень доверия 0.938
#
# Параметр θ = 0.4, размер выборки 60
#  Способ 1 : средняя длина 0.24594010098984695, уровень доверия 0.943
#  Способ 2 : средняя длина 0.24332413163434463, уровень доверия 0.959
#
# Параметр θ = 0.4, размер выборки 62
#  Способ 1 : средняя длина 0.241907369469872, уровень доверия 0.943
#  Способ 2 : средняя длина 0.23941703993598543, уровень доверия 0.943
#
# Параметр θ = 0.4, размер выборки 64
#  Способ 1 : средняя длина 0.23797575709298271, уровень доверия 0.94
#  Способ 2 : средняя длина 0.2356022299453408, уровень доверия 0.94
#
# Параметр θ = 0.4, размер выборки 66
#  Способ 1 : средняя длина 0.23459550337032808, уровень доверия 0.943
#  Способ 2 : средняя длина 0.2323263873080592, уровень доверия 0.956
#
# Параметр θ = 0.4, размер выборки 68
#  Способ 1 : средняя длина 0.23124519079015063, уровень доверия 0.952
#  Способ 2 : средняя длина 0.2290740802439803, уровень доверия 0.952
#
# Параметр θ = 0.4, размер выборки 70
#  Способ 1 : средняя длина 0.22780419555412545, уровень доверия 0.954
#  Способ 2 : средняя длина 0.2257263327348439, уровень доверия 0.954
#
# Параметр θ = 0.4, размер выборки 72
#  Способ 1 : средняя длина 0.2246669727596771, уровень доверия 0.932
#  Способ 2 : средняя длина 0.22267449704521441, уровень доверия 0.953
#
# Параметр θ = 0.4, размер выборки 74
#  Способ 1 : средняя длина 0.22169324880823985, уровень доверия 0.957
#  Способ 2 : средняя длина 0.21978014575881827, уровень доверия 0.942
#
# Параметр θ = 0.4, размер выборки 76
#  Способ 1 : средняя длина 0.21865075139928092, уровень доверия 0.955
#  Способ 2 : средняя длина 0.21681343197805586, уровень доверия 0.955
#
# Параметр θ = 0.4, размер выборки 78
#  Способ 1 : средняя длина 0.21590516627692594, уровень доверия 0.925
#  Способ 2 : средняя длина 0.21413732258952872, уровень доверия 0.941
#
# Параметр θ = 0.4, размер выборки 80
#  Способ 1 : средняя длина 0.21328651907950763, уровень доверия 0.932
#  Способ 2 : средняя длина 0.21158367223529403, уровень доверия 0.932
#
# Параметр θ = 0.4, размер выборки 82
#  Способ 1 : средняя длина 0.2106632560023944, уровень доверия 0.944
#  Способ 2 : средняя длина 0.20902227881356975, уровень доверия 0.944
#
# Параметр θ = 0.4, размер выборки 84
#  Способ 1 : средняя длина 0.2083198779709637, уровень доверия 0.932
#  Способ 2 : средняя длина 0.20673570261172028, уровень доверия 0.932
#
# Параметр θ = 0.4, размер выборки 86
#  Способ 1 : средняя длина 0.20571615582128505, уровень доверия 0.933
#  Способ 2 : средняя длина 0.2041880801088646, уровень доверия 0.949
#
# Параметр θ = 0.4, размер выборки 88
#  Способ 1 : средняя длина 0.20340003955928831, уровень доверия 0.947
#  Способ 2 : средняя длина 0.20192343116913639, уровень доверия 0.947
#
# Параметр θ = 0.4, размер выборки 90
#  Способ 1 : средняя длина 0.20124057494810269, уровень доверия 0.948
#  Способ 2 : средняя длина 0.19981203931522798, уровень доверия 0.948
#
# Параметр θ = 0.4, размер выборки 92
#  Способ 1 : средняя длина 0.19903755156181765, уровень доверия 0.944
#  Способ 2 : средняя длина 0.19765530543437643, уровень доверия 0.957
#
# Параметр θ = 0.4, размер выборки 94
#  Способ 1 : средняя длина 0.19698763140945147, уровень доверия 0.969
#  Способ 2 : средняя длина 0.19564866837734507, уровень доверия 0.969
#
# Параметр θ = 0.4, размер выборки 96
#  Способ 1 : средняя длина 0.1950113914455486, уровень доверия 0.966
#  Способ 2 : средняя длина 0.19371342125222013, уровень доверия 0.957
#
# Параметр θ = 0.4, размер выборки 98
#  Способ 1 : средняя длина 0.19317259070530962, уровень доверия 0.933
#  Способ 2 : средняя длина 0.1919130473106593, уровень доверия 0.943
# Параметр θ = 0.5, размер выборки 20
#  Способ 1 : средняя длина 0.4268913432975072, уровень доверия 0.96
#  Способ 2 : средняя длина 0.41335627275644904, уровень доверия 0.96
#
# Параметр θ = 0.5, размер выборки 22
#  Способ 1 : средняя длина 0.4083076935133323, уровень доверия 0.947
#  Способ 2 : средняя длина 0.39652845047400326, уровень доверия 0.947
#
# Параметр θ = 0.5, размер выборки 24
#  Способ 1 : средняя длина 0.392109413058048, уровень доверия 0.944
#  Способ 2 : средняя длина 0.3817325849564694, уровень доверия 0.944
#
# Параметр θ = 0.5, размер выборки 26
#  Способ 1 : средняя длина 0.37720151966609355, уровень доверия 0.927
#  Способ 2 : средняя длина 0.36798140889165937, уровень доверия 0.927
#
# Параметр θ = 0.5, размер выборки 28
#  Способ 1 : средняя длина 0.36375152958297, уровень доверия 0.92
#  Способ 2 : средняя длина 0.3554909200765161, уровень доверия 0.968
#
# Параметр θ = 0.5, размер выборки 30
#  Способ 1 : средняя длина 0.3522142115452958, уровень доверия 0.971
#  Способ 2 : средняя длина 0.3447454328867255, уровень доверия 0.971
#
# Параметр θ = 0.5, размер выборки 32
#  Способ 1 : средняя длина 0.34063161989287816, уровень доверия 0.94
#  Способ 2 : средняя длина 0.3338571894990515, уровень доверия 0.94
#
# Параметр θ = 0.5, размер выборки 34
#  Способ 1 : средняя длина 0.3313967158378091, уровень доверия 0.943
#  Способ 2 : средняя длина 0.32519144891732255, уровень доверия 0.943
#
# Параметр θ = 0.5, размер выборки 36
#  Способ 1 : средняя длина 0.3219583999633106, уровень доверия 0.93
#  Способ 2 : средняя длина 0.31626299275621494, уровень доверия 0.93
#
# Параметр θ = 0.5, размер выборки 38
#  Способ 1 : средняя длина 0.31338161117816127, уровень доверия 0.912
#  Способ 2 : средняя длина 0.30812822391430683, уровень доверия 0.912
#
# Параметр θ = 0.5, размер выборки 40
#  Способ 1 : средняя длина 0.30594573885459553, уровень доверия 0.927
#  Способ 2 : средняя длина 0.3010722081591263, уровень доверия 0.962
#
# Параметр θ = 0.5, размер выборки 42
#  Способ 1 : средняя длина 0.299025261895152, уровень доверия 0.963
#  Способ 2 : средняя длина 0.2944877559775961, уровень доверия 0.963
#
# Параметр θ = 0.5, размер выборки 44
#  Способ 1 : средняя длина 0.2921950500734116, уровень доверия 0.952
#  Способ 2 : средняя длина 0.28796184712572814, уровень доверия 0.952
#
# Параметр θ = 0.5, размер выборки 46
#  Способ 1 : средняя длина 0.285672893058761, уровень доверия 0.947
#  Способ 2 : средняя длина 0.2817133729130545, уровень доверия 0.947
#
# Параметр θ = 0.5, размер выборки 48
#  Способ 1 : средняя длина 0.27983742002280676, уровень доверия 0.944
#  Способ 2 : средняя длина 0.2761197445237518, уровень доверия 0.944
#
# Параметр θ = 0.5, размер выборки 50
#  Способ 1 : средняя длина 0.27431939972014246, уровень доверия 0.929
#  Способ 2 : средняя длина 0.27082024639770885, уровень доверия 0.929
#
# Параметр θ = 0.5, размер выборки 52
#  Способ 1 : средняя длина 0.269229228151968, уровень доверия 0.935
#  Способ 2 : средняя длина 0.2659266013938684, уровень доверия 0.935
#
# Параметр θ = 0.5, размер выборки 54
#  Способ 1 : средняя длина 0.2642794935812679, уровень доверия 0.931
#  Способ 2 : средняя длина 0.2611572285694624, уровень доверия 0.96
#
# Параметр θ = 0.5, размер выборки 56
#  Способ 1 : средняя длина 0.25943804155881756, уровень доверия 0.947
#  Способ 2 : средняя длина 0.2564820658208007, уровень доверия 0.947
#
# Параметр θ = 0.5, размер выборки 58
#  Способ 1 : средняя длина 0.25522655082015294, уровень доверия 0.958
#  Способ 2 : средняя длина 0.25241850321880377, уровень доверия 0.958
#
# Параметр θ = 0.5, размер выборки 60
#  Способ 1 : средняя длина 0.2510473211299538, уровень доверия 0.958
#  Способ 2 : средняя длина 0.24837702825695862, уровень доверия 0.958
#
# Параметр θ = 0.5, размер выборки 62
#  Способ 1 : средняя длина 0.24685761524490224, уровень доверия 0.939
#  Способ 2 : средняя длина 0.24431632511696438, уровень доверия 0.939
#
# Параметр θ = 0.5, размер выборки 64
#  Способ 1 : средняя длина 0.24300884585298307, уровень доверия 0.938
#  Способ 2 : средняя длина 0.24058511958861484, уровень доверия 0.938
#
# Параметр θ = 0.5, размер выборки 66
#  Способ 1 : средняя длина 0.2393859578568701, уровень доверия 0.932
#  Способ 2 : средняя длина 0.2370705063062188, уровень доверия 0.932
#
# Параметр θ = 0.5, размер выборки 68
#  Способ 1 : средняя длина 0.23586335951710105, уровень доверия 0.927
#  Способ 2 : средняя длина 0.23364888999428426, уровень доверия 0.956
#
# Параметр θ = 0.5, размер выборки 70
#  Способ 1 : средняя длина 0.23255654274078316, уровень доверия 0.937
#  Способ 2 : средняя длина 0.2304353324954393, уровень доверия 0.964
#
# Параметр θ = 0.5, размер выборки 72
#  Способ 1 : средняя длина 0.2294456603780338, уровень доверия 0.964
#  Способ 2 : средняя длина 0.22741080451792875, уровень доверия 0.964
#
# Параметр θ = 0.5, размер выборки 74
#  Способ 1 : средняя длина 0.22617188573816255, уровень доверия 0.952
#  Способ 2 : средняя длина 0.2242201342679436, уровень доверия 0.952
#
# Параметр θ = 0.5, размер выборки 76
#  Способ 1 : средняя длина 0.22328407918737012, уровень доверия 0.939
#  Способ 2 : средняя длина 0.22140782597298184, уровень доверия 0.939
#
# Параметр θ = 0.5, размер выборки 78
#  Способ 1 : средняя длина 0.22048132260557532, уровень доверия 0.944
#  Способ 2 : средняя длина 0.21867600909187587, уровень доверия 0.944
#
# Параметр θ = 0.5, размер выборки 80
#  Способ 1 : средняя длина 0.2177438062618092, уровень доверия 0.942
#  Способ 2 : средняя длина 0.21600537312060464, уровень доверия 0.942
#
# Параметр θ = 0.5, размер выборки 82
#  Способ 1 : средняя длина 0.21502300049180065, уровень доверия 0.925
#  Способ 2 : средняя длина 0.2133480627471962, уровень доверия 0.925
#
# Параметр θ = 0.5, размер выборки 84
#  Способ 1 : средняя длина 0.2126590749887256, уровень доверия 0.949
#  Способ 2 : средняя длина 0.2110419020631366, уровень доверия 0.949
#
# Параметр θ = 0.5, размер выборки 86
#  Способ 1 : средняя длина 0.21011574767423877, уровень доверия 0.941
#  Способ 2 : средняя длина 0.20855499144905928, уровень доверия 0.965
#
# Параметр θ = 0.5, размер выборки 88
#  Способ 1 : средняя длина 0.20765544513001152, уровень доверия 0.924
#  Способ 2 : средняя длина 0.20614794408328568, уровень доверия 0.949
#
# Параметр θ = 0.5, размер выборки 90
#  Способ 1 : средняя длина 0.20541573312517544, уровень доверия 0.95
#  Способ 2 : средняя длина 0.20395755952177533, уровень доверия 0.95
#
# Параметр θ = 0.5, размер выборки 92
#  Способ 1 : средняя длина 0.20321149717211717, уровень доверия 0.949
#  Способ 2 : средняя длина 0.2018002644533985, уровень доверия 0.949
#
# Параметр θ = 0.5, размер выборки 94
#  Способ 1 : средняя длина 0.2010600742736175, уровень доверия 0.949
#  Способ 2 : средняя длина 0.19969343005967008, уровень доверия 0.949
#
# Параметр θ = 0.5, размер выборки 96
#  Способ 1 : средняя длина 0.19896701310780815, уровень доверия 0.946
#  Способ 2 : средняя длина 0.19764271481653814, уровень доверия 0.946
#
# Параметр θ = 0.5, размер выборки 98
#  Способ 1 : средняя длина 0.19697398064994395, уровень доверия 0.947
#  Способ 2 : средняя длина 0.1956896510494568, уровень доверия 0.947
# Параметр θ = 0.9, размер выборки 20
#  Способ 1 : средняя длина 0.23724343241171386, уровень доверия 0.883
#  Способ 2 : средняя длина 0.2297213623498306, уровень доверия 0.873
#
# Параметр θ = 0.9, размер выборки 22
#  Способ 1 : средняя длина 0.22785116691021662, уровень доверия 0.906
#  Способ 2 : средняя длина 0.22127790288784138, уровень доверия 0.895
#
# Параметр θ = 0.9, размер выборки 24
#  Способ 1 : средняя длина 0.2177906406081553, уровень доверия 0.906
#  Способ 2 : средняя длина 0.21202700432587887, уровень доверия 0.888
#
# Параметр θ = 0.9, размер выборки 26
#  Способ 1 : средняя длина 0.2110559545095105, уровень доверия 0.932
#  Способ 2 : средняя длина 0.20589701643867706, уровень доверия 0.925
#
# Параметр θ = 0.9, размер выборки 28
#  Способ 1 : средняя длина 0.2039259926565522, уровень доверия 0.934
#  Способ 2 : средняя длина 0.19929493860852368, уровень доверия 0.924
#
# Параметр θ = 0.9, размер выборки 30
#  Способ 1 : средняя длина 0.20619036578103217, уровень доверия 0.828
#  Способ 2 : средняя длина 0.20181805440611156, уровень доверия 0.933
#
# Параметр θ = 0.9, размер выборки 32
#  Способ 1 : средняя длина 0.19733536873215404, уровень доверия 0.841
#  Способ 2 : средняя длина 0.19341079261635924, уровень доверия 0.945
#
# Параметр θ = 0.9, размер выборки 34
#  Способ 1 : средняя длина 0.1910410188995189, уровень доверия 0.858
#  Способ 2 : средняя длина 0.18746385455727058, уровень доверия 0.956
#
# Параметр θ = 0.9, размер выборки 36
#  Способ 1 : средняя длина 0.18480348060881954, уровень доверия 0.884
#  Способ 2 : средняя длина 0.18153432821063462, уровень доверия 0.969
#
# Параметр θ = 0.9, размер выборки 38
#  Способ 1 : средняя длина 0.18150544731903417, уровень доверия 0.889
#  Способ 2 : средняя длина 0.1784627722824191, уровень доверия 0.978
#
# Параметр θ = 0.9, размер выборки 40
#  Способ 1 : средняя длина 0.17830381257812672, уровень доверия 0.915
#  Способ 2 : средняя длина 0.17546354061692226, уровень доверия 0.912
#
# Параметр θ = 0.9, размер выборки 42
#  Способ 1 : средняя длина 0.17424715686589184, уровень доверия 0.911
#  Способ 2 : средняя длина 0.17160307422088267, уровень доверия 0.892
#
# Параметр θ = 0.9, размер выборки 44
#  Способ 1 : средняя длина 0.16959968434156936, уровень доверия 0.937
#  Способ 2 : средняя длина 0.16714259315025537, уровень доверия 0.937
#
# Параметр θ = 0.9, размер выборки 46
#  Способ 1 : средняя длина 0.16737647265675393, уровень доверия 0.937
#  Способ 2 : средняя длина 0.16505657976000157, уровень доверия 0.932
#
# Параметр θ = 0.9, размер выборки 48
#  Способ 1 : средняя длина 0.16478998857838323, уровень доверия 0.876
#  Способ 2 : средняя длина 0.16260073274913253, уровень доверия 0.949
#
# Параметр θ = 0.9, размер выборки 50
#  Способ 1 : средняя длина 0.1609654085659713, уровень доверия 0.878
#  Способ 2 : средняя длина 0.15891217192009385, уровень доверия 0.931
#
# Параметр θ = 0.9, размер выборки 52
#  Способ 1 : средняя длина 0.15880957680377691, уровень доверия 0.903
#  Способ 2 : средняя длина 0.15686146455238884, уровень доверия 0.954
#
# Параметр θ = 0.9, размер выборки 54
#  Способ 1 : средняя длина 0.15585485225183873, уровень доверия 0.915
#  Способ 2 : средняя длина 0.15401354347107857, уровень доверия 0.957
#
# Параметр θ = 0.9, размер выборки 56
#  Способ 1 : средняя длина 0.15286344063462484, уровень доверия 0.916
#  Способ 2 : средняя длина 0.15112175071501727, уровень доверия 0.901
#
# Параметр θ = 0.9, размер выборки 58
#  Способ 1 : средняя длина 0.15102736154379443, уровень доверия 0.928
#  Способ 2 : средняя длина 0.1493657318310614, уровень доверия 0.919
#
# Параметр θ = 0.9, размер выборки 60
#  Способ 1 : средняя длина 0.14920675341305192, уровень доверия 0.946
#  Способ 2 : средняя длина 0.14761969911409215, уровень доверия 0.938
#
# Параметр θ = 0.9, размер выборки 62
#  Способ 1 : средняя длина 0.14476710913364266, уровень доверия 0.939
#  Способ 2 : средняя длина 0.14327679567936083, уровень доверия 0.928
#
# Параметр θ = 0.9, размер выборки 64
#  Способ 1 : средняя длина 0.14313546211695768, уровень доверия 0.882
#  Способ 2 : средняя длина 0.14170785491328725, уровень доверия 0.958
#
# Параметр θ = 0.9, размер выборки 66
#  Способ 1 : средняя длина 0.14241509248822398, уровень доверия 0.899
#  Способ 2 : средняя длина 0.14103758793578425, уровень доверия 0.951
#
# Параметр θ = 0.9, размер выборки 68
#  Способ 1 : средняя длина 0.14002137649725455, уровень доверия 0.908
#  Способ 2 : средняя длина 0.1387067464019703, уровень доверия 0.957
#
# Параметр θ = 0.9, размер выборки 70
#  Способ 1 : средняя длина 0.1378799914159293, уровень доверия 0.925
#  Способ 2 : средняя длина 0.13662235124389854, уровень доверия 0.961
#
# Параметр θ = 0.9, размер выборки 72
#  Способ 1 : средняя длина 0.13664599798953814, уровень доверия 0.932
#  Способ 2 : средняя длина 0.13543414281951316, уровень доверия 0.92
#
# Параметр θ = 0.9, размер выборки 74
#  Способ 1 : средняя длина 0.13279946276771898, уровень доверия 0.919
#  Способ 2 : средняя длина 0.13165346910959808, уровень доверия 0.912
#
# Параметр θ = 0.9, размер выборки 76
#  Способ 1 : средняя длина 0.13239184468060797, уровень доверия 0.951
#  Способ 2 : средняя длина 0.13127935773104668, уровень доверия 0.943
#
# Параметр θ = 0.9, размер выборки 78
#  Способ 1 : средняя длина 0.12954106413090963, уровень доверия 0.953
#  Способ 2 : средняя длина 0.1284803745863676, уровень доверия 0.938
#
# Параметр θ = 0.9, размер выборки 80
#  Способ 1 : средняя длина 0.12830963851684518, уровень доверия 0.914
#  Способ 2 : средняя длина 0.1272852340492138, уровень доверия 0.945
#
# Параметр θ = 0.9, размер выборки 82
#  Способ 1 : средняя длина 0.1284548870907167, уровень доверия 0.917
#  Способ 2 : средняя длина 0.12745427814016239, уровень доверия 0.95
#
# Параметр θ = 0.9, размер выборки 84
#  Способ 1 : средняя длина 0.12615995551968492, уровень доверия 0.923
#  Способ 2 : средняя длина 0.12520056799121587, уровень доверия 0.95
#
# Параметр θ = 0.9, размер выборки 86
#  Способ 1 : средняя длина 0.1253727886490382, уровень доверия 0.924
#  Способ 2 : средняя длина 0.12444150975862638, уровень доверия 0.954
#
# Параметр θ = 0.9, размер выборки 88
#  Способ 1 : средняя длина 0.12382301065487762, уровень доверия 0.943
#  Способ 2 : средняя длина 0.12292410180105924, уровень доверия 0.943
#
# Параметр θ = 0.9, размер выборки 90
#  Способ 1 : средняя длина 0.12204679602147896, уровень доверия 0.945
#  Способ 2 : средняя длина 0.12118042900260198, уровень доверия 0.938
#
# Параметр θ = 0.9, размер выборки 92
#  Способ 1 : средняя длина 0.12023245157310877, уровень доверия 0.957
#  Способ 2 : средняя длина 0.1193974792813195, уровень доверия 0.947
#
# Параметр θ = 0.9, размер выборки 94
#  Способ 1 : средняя длина 0.11939940564627168, уровень доверия 0.911
#  Способ 2 : средняя длина 0.11858782479181926, уровень доверия 0.949
#
# Параметр θ = 0.9, размер выборки 96
#  Способ 1 : средняя длина 0.11754929365974476, уровень доверия 0.912
#  Способ 2 : средняя длина 0.11676690100931456, уровень доверия 0.948
#
# Параметр θ = 0.9, размер выборки 98
#  Способ 1 : средняя длина 0.11721556612805555, уровень доверия 0.946
#  Способ 2 : средняя длина 0.11645128538031727, уровень доверия 0.964
